# %%
# %pip install rich # 출력 관련 유틸 라이브러리
# %pip install bs4
# %pip install selenium
# Out:
# Requirement already satisfied: rich in /opt/homebrew/lib/python3.13/site-packages (14.0.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/homebrew/lib/python3.13/site-packages (from rich) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/bankai/Library/Python/3.13/lib/python/site-packages (from rich) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /opt/homebrew/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: bs4 in /opt/homebrew/lib/python3.13/site-packages (0.0.2)
# Requirement already satisfied: beautifulsoup4 in /opt/homebrew/lib/python3.13/site-packages (from bs4) (4.13.4)
# Requirement already satisfied: soupsieve>1.2 in /opt/homebrew/lib/python3.13/site-packages (from beautifulsoup4->bs4) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/homebrew/lib/python3.13/site-packages (from beautifulsoup4->bs4) (4.13.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: selenium in /opt/homebrew/lib/python3.13/site-packages (4.31.0)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/homebrew/lib/python3.13/site-packages (from urllib3[socks]<3,>=1.26->selenium) (2.4.0)
# Requirement already satisfied: trio~=0.17 in /opt/homebrew/lib/python3.13/site-packages (from selenium) (0.30.0)
# Requirement already satisfied: trio-websocket~=0.9 in /opt/homebrew/lib/python3.13/site-packages (from selenium) (0.12.2)
# Requirement already satisfied: certifi>=2021.10.8 in /opt/homebrew/lib/python3.13/site-packages (from selenium) (2025.1.31)
# Requirement already satisfied: typing_extensions~=4.9 in /opt/homebrew/lib/python3.13/site-packages (from selenium) (4.13.2)
# Requirement already satisfied: websocket-client~=1.8 in /opt/homebrew/lib/python3.13/site-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in /opt/homebrew/lib/python3.13/site-packages (from trio~=0.17->selenium) (25.3.0)
# Requirement already satisfied: sortedcontainers in /opt/homebrew/lib/python3.13/site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /opt/homebrew/lib/python3.13/site-packages (from trio~=0.17->selenium) (3.10)
# Requirement already satisfied: outcome in /opt/homebrew/lib/python3.13/site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /opt/homebrew/lib/python3.13/site-packages (from trio~=0.17->selenium) (1.3.1)
# Requirement already satisfied: wsproto>=0.14 in /opt/homebrew/lib/python3.13/site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /opt/homebrew/lib/python3.13/site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /opt/homebrew/lib/python3.13/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from urllib.parse import quote_plus
from urllib.request import urlopen
from bs4 import BeautifulSoup as bs
import matplotlib.pyplot as plt

from rich.console import Console
from rich.style import Style
from rich.theme import Theme

white = {
    'highlight': False,
    'style': Style(color="rgb(220,220,220)", italic=False, bold=True),
}

console = Console(theme=Theme({"repr.number": Style(color="bright_yellow", italic=True),}))
pprint = console.print

# %%
def get_html_soup(url):
    try:
        html = urlopen(url)
    except:
        from requests import get
        response = get(url)
        html = response._content
    soup = bs(html, "html.parser")
    return soup


def save_image(img_url, file_path):
    with open(file_path, 'wb') as f: # w: write, b: binary
        byte = urlopen(img_url).read()
        f.write(byte)


def show_image(image, axis='off', cmap=None, size=5):
    plt.figure(figsize = (size,size))
    plt.imshow(image)
    plt.axis(axis)
    plt.show()


def show_images(*images, axis='off', cmap=None, size=25):
    fig, axes = plt.subplots(1, len(images), figsize = (size, size))
    for image, ax in zip(images, axes):
      ax.imshow(image, cmap=cmap)
      ax.axis(axis)
    plt.show()

# %%
query = input('검색어: ')
url = 'https://stackframe.tistory.com/' # quote_plus(): 한글도 url에 쓸 수 있도록 인코딩해 주는 함수
print('가져올 페이지: ' + url)
soup = get_html_soup(url)
# Out:
# 가져올 페이지: https://stackframe.tistory.com/

# %%
from rich.syntax import Syntax

def print_html(soup):
    if not isinstance(soup, bs):
        soup = bs(str(soup), "html.parser")

    syntax = Syntax(soup.prettify(), "html", theme="monokai", line_numbers=True, word_wrap=True)
    pprint(syntax)


print_html(soup)
# Out:
#     1 <!DOCTYPE html>
#     2 <html lang="ko">
#     3  <head>
#     4   <script type="text/javascript">
#     5    if (!window.T) { window.T = {} }
#     6 window.T.config =
#       {"TOP_SSL_URL":"https://www.tistory.com","PREVIEW":false,"ROLE":"guest","PREV_PAGE":"","NEXT_PAGE":"","BLOG":
#       {"id":2982309,"name":"stackframe","title":"stackframe","isDormancy":true,"nickName":"stackframe","status":"op
#       en","profileStatus":"normal"},"NEED_COMMENT_LOGIN":false,"COMMENT_LOGIN_CONFIRM_MESSAGE":"","LOGIN_URL":"http
#       s://www.tistory.com/auth/login/?redirectUrl=https://stackframe.tistory.com/","DEFAULT_URL":"https://stackfram
#       e.tistory.com","USER":{"name":null,"homepage":null,"id":0,"profileImage":null},"SUBSCRIPTION":{"status":"none
#       ","isConnected":false,"isPending":false,"isWait":false,"isProcessing":false,"isNone":true},"IS_LOGIN":false,"
#       HAS_BLOG":false,"IS_SUPPORT":false,"IS_SCRAPABLE":false,"TOP_URL":"http://www.tistory.com","JOIN_URL":"https:
#       //www.tistory.com/member/join","PHASE":"prod","ROLE_GROUP":"visitor"};
#     7 window.T.entryInfo = null;
#     8 window.appInfo =
#       {"domain":"tistory.com","topUrl":"https://www.tistory.com","loginUrl":"https://www.tistory.com/auth/login","l
#       ogoutUrl":"https://www.tistory.com/auth/logout"};
#     9 window.initData = {};
#    10
#    11 window.TistoryBlog = {
#    12     basePath: "",
#    13     url: "https://stackframe.tistory.com",
#    14     tistoryUrl: "https://stackframe.tistory.com",
#    15     manageUrl: "https://stackframe.tistory.com/manage",
#    16     token: "S+Yfy6sKkiT4w540YXPTQcOt8bdoIKWzREpaESoRz5/zbiEf81wvrC528mrGLzjt"
#    17 };
#    18 var servicePath = "";
#    19 var blogURL = "";
#    20   </script>
#    21   <!-- BusinessLicenseInfo - START -->
#    22   <link
#       href="https://tistory1.daumcdn.net/tistory_admin/userblog/userblog-2f42fbf504a9342b3fd8297ed4953c4384cc5c1f/s
#       tatic/plugin/BusinessLicenseInfo/style.css" rel="stylesheet" type="text/css"/>
#    23   <script>
#    24    function switchFold(entryId) {
#    25     var businessLayer = document.getElementById("businessInfoLayer_" + entryId);
#    26
#    27     if (businessLayer) {
#    28         if (businessLayer.className.indexOf("unfold_license") > 0) {
#    29             businessLayer.className = "business_license_layer";
#    30         } else {
#    31             businessLayer.className = "business_license_layer unfold_license";
#    32         }
#    33     }
#    34 }
#    35   </script>
#    36   <!-- BusinessLicenseInfo - END -->
#    37   <!-- GoogleAnalytics - START -->
#    38   <script async="async" src="https://www.googletagmanager.com/gtag/js?id=G-3JMH45GWRQ">
#    39   </script>
#    40   <script>
#    41    window.dataLayer = window.dataLayer || [];
#    42 function gtag(){dataLayer.push(arguments);}
#    43 gtag('js', new Date());
#    44 gtag('config','G-3JMH45GWRQ', {
#    45     cookie_domain: 'auto',
#    46     cookie_flags: 'max-age=0;domain=.tistory.com',
#    47     cookie_expires: 7 * 24 * 60 * 60 // 7 days, in seconds
#    48 });
#    49   </script>
#    50   <!-- GoogleAnalytics - END -->
#    51   <!-- MetaTag - START -->
#    52   <meta content="799054dfe060b26bfa6fc7f6f32c8513f24cacba" name="naver-site-verification"/>
#    53   <meta content="3eQv5bBRp1yXXjUTJuSNfqKk9zDG2kJjqFTwHX_yl3A" name="google-site-verification"/>
#    54   <!-- MetaTag - END -->
#    55   <!-- System - START -->
#    56   <!-- System - END -->
#    57   <!-- TistoryProfileLayer - START -->
#    58   <link
#       href="https://tistory1.daumcdn.net/tistory_admin/userblog/userblog-2f42fbf504a9342b3fd8297ed4953c4384cc5c1f/s
#       tatic/plugin/TistoryProfileLayer/style.css" rel="stylesheet" type="text/css"/>
#    59   <script
#       src="https://tistory1.daumcdn.net/tistory_admin/userblog/userblog-2f42fbf504a9342b3fd8297ed4953c4384cc5c1f/st
#       atic/plugin/TistoryProfileLayer/script.js" type="text/javascript">
#    60   </script>
#    61   <!-- TistoryProfileLayer - END -->
#    62   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#    63   <meta content="telephone=no" name="format-detection"/>
#    64   <script crossorigin="anonymous" integrity="sha256-9/aliU8dGd2tb6OSsuzixeV4y/faTqgFtohetphbbj0="
#       src="//t1.daumcdn.net/tistory_admin/lib/jquery/jquery-3.5.1.min.js">
#    65   </script>
#    66   <script src="//t1.daumcdn.net/tiara/js/v1/tiara.min.js" type="text/javascript">
#    67   </script>
#    68   <meta content="always" name="referrer">
#    69    <meta content="ca-host-pub-9691043933427338" name="google-adsense-platform-account">
#    70     <meta content="tistory.com" name="google-adsense-platform-domain"/>
#    71     <meta content="" name="description"/>
#    72     <!-- BEGIN OPENGRAPH -->
#    73     <meta content="website" property="og:type"/>
#    74     <meta content="https://stackframe.tistory.com" property="og:url"/>
#    75     <meta content="stackframe" property="og:site_name"/>
#    76     <meta content="stackframe" property="og:title"/>
#    77     <meta content="" property="og:description"/>
#    78     <meta
#       content="https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https%3A%2F%2Ft1.daumcdn.net%2Ftist
#       ory_admin%2Fstatic%2Fmanage%2Fimages%2Fr3%2Fdefault_L.png" property="og:image"/>
#    79     <meta content="'stackframe'" property="og:article:author"/>
#    80     <!-- END OPENGRAPH -->
#    81     <!-- BEGIN TWITTERCARD -->
#    82     <meta content="summary_large_image" name="twitter:card"/>
#    83     <meta content="@TISTORY" name="twitter:site"/>
#    84     <meta content="stackframe" name="twitter:title"/>
#    85     <meta content="" name="twitter:description"/>
#    86     <meta
#       content="https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https%3A%2F%2Ft1.daumcdn.net%2Ftist
#       ory_admin%2Fstatic%2Fmanage%2Fimages%2Fr3%2Fdefault_L.png" property="twitter:image"/>
#    87     <!-- END TWITTERCARD -->
#    88     <script defer=""
#       src="https://tistory1.daumcdn.net/tistory_admin/userblog/userblog-2f42fbf504a9342b3fd8297ed4953c4384cc5c1f/st
#       atic/pc/dist/index.js" type="module">
#    89     </script>
#    90     <script defer="" nomodule="true"
#       src="https://tistory1.daumcdn.net/tistory_admin/userblog/userblog-2f42fbf504a9342b3fd8297ed4953c4384cc5c1f/st
#       atic/pc/dist/index-legacy.js" type="text/javascript">
#    91     </script>
#    92     <script defer="" nomodule="true"
#       src="https://tistory1.daumcdn.net/tistory_admin/userblog/userblog-2f42fbf504a9342b3fd8297ed4953c4384cc5c1f/st
#       atic/pc/dist/polyfills-legacy.js" type="text/javascript">
#    93     </script>
#    94     <link href="https://t1.daumcdn.net/tistory_admin/favicon/tistory_favicon_32x32.ico" rel="icon"
#       sizes="any"/>
#    95     <link href="https://t1.daumcdn.net/tistory_admin/top_v2/bi-tistory-favicon.svg" rel="icon"
#       type="image/svg+xml"/>
#    96     <link href="https://t1.daumcdn.net/tistory_admin/top_v2/tistory-apple-touch-favicon.png"
#       rel="apple-touch-icon"/>
#    97     <link href="https://t1.daumcdn.net/tistory_admin/www/style/font.css" rel="stylesheet" type="text/css"/>
#    98     <link
#       href="https://tistory1.daumcdn.net/tistory_admin/userblog/userblog-2f42fbf504a9342b3fd8297ed4953c4384cc5c1f/s
#       tatic/style/content.css" rel="stylesheet" type="text/css"/>
#    99     <link
#       href="https://tistory1.daumcdn.net/tistory_admin/userblog/userblog-2f42fbf504a9342b3fd8297ed4953c4384cc5c1f/s
#       tatic/pc/dist/index.css" rel="stylesheet" type="text/css"/>
#   100     <link
#       href="https://tistory1.daumcdn.net/tistory_admin/userblog/userblog-2f42fbf504a9342b3fd8297ed4953c4384cc5c1f/s
#       tatic/style/uselessPMargin.css" rel="stylesheet" type="text/css"/>
#   101     <script type="text/javascript">
#   102      (function() {
#   103     var tjQuery = jQuery.noConflict(true);
#   104     window.tjQuery = tjQuery;
#   105     window.orgjQuery = window.jQuery; window.jQuery = tjQuery;
#   106     window.jQuery = window.orgjQuery; delete window.orgjQuery;
#   107 })()
#   108     </script>
#   109     <script
#       src="https://tistory1.daumcdn.net/tistory_admin/userblog/userblog-2f42fbf504a9342b3fd8297ed4953c4384cc5c1f/st
#       atic/script/base.js" type="text/javascript">
#   110     </script>
#   111     <script src="//developers.kakao.com/sdk/js/kakao.min.js" type="text/javascript">
#   112     </script>
#   113     <meta charset="utf-8"/>
#   114     <meta content="user-scalable=no, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0,
#       width=device-width" name="viewport"/>
#   115     <meta content="632eec860ef7f0cfdd4857b66ac6396e0a82b3b7" name="naver-site-verification">
#   116      <title>
#   117       stackframe
#   118      </title>
#   119      <link href="https://tistory1.daumcdn.net/tistory/2982309/skin/style.css?_version_=1624887901"
#       rel="stylesheet"/>
#   120      <script src="//t1.daumcdn.net/tistory_admin/lib/jquery/jquery-1.12.4.min.js">
#   121      </script>
#   122      <script defer="" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#   123      </script>
#   124      <script>
#   125       var pub = "c" + "a-p" + "ub-86" + "3484378"+ "8076906";
#   126     console.log(pub);
#   127 (adsbygoogle=window.adsbygoogle||[]).push({
#   128         google_ad_client: pub,
#   129         enable_page_level_ads: true,
#   130     });
#   131      </script>
#   132      <style>
#   133       pre
#   134         {
#   135             white-space:pre !important;
#   136         }
#   137         .entry-content
#   138         {
#   139             word-break:break-all;
#   140         }
#   141      </style>
#   142      <style type="text/css">
#   143       .another_category {
#   144     border: 1px solid #E5E5E5;
#   145     padding: 10px 10px 5px;
#   146     margin: 10px 0;
#   147     clear: both;
#   148 }
#   149
#   150 .another_category h4 {
#   151     font-size: 12px !important;
#   152     margin: 0 !important;
#   153     border-bottom: 1px solid #E5E5E5 !important;
#   154     padding: 2px 0 6px !important;
#   155 }
#   156
#   157 .another_category h4 a {
#   158     font-weight: bold !important;
#   159 }
#   160
#   161 .another_category table {
#   162     table-layout: fixed;
#   163     border-collapse: collapse;
#   164     width: 100% !important;
#   165     margin-top: 10px !important;
#   166 }
#   167
#   168 * html .another_category table {
#   169     width: auto !important;
#   170 }
#   171
#   172 *:first-child + html .another_category table {
#   173     width: auto !important;
#   174 }
#   175
#   176 .another_category th, .another_category td {
#   177     padding: 0 0 4px !important;
#   178 }
#   179
#   180 .another_category th {
#   181     text-align: left;
#   182     font-size: 12px !important;
#   183     font-weight: normal;
#   184     word-break: break-all;
#   185     overflow: hidden;
#   186     line-height: 1.5;
#   187 }
#   188
#   189 .another_category td {
#   190     text-align: right;
#   191     width: 80px;
#   192     font-size: 11px;
#   193 }
#   194
#   195 .another_category th a {
#   196     font-weight: normal;
#   197     text-decoration: none;
#   198     border: none !important;
#   199 }
#   200
#   201 .another_category th a.current {
#   202     font-weight: bold;
#   203     text-decoration: none !important;
#   204     border-bottom: 1px solid !important;
#   205 }
#   206
#   207 .another_category th span {
#   208     font-weight: normal;
#   209     text-decoration: none;
#   210     font: 10px Tahoma, Sans-serif;
#   211     border: none !important;
#   212 }
#   213
#   214 .another_category_color_gray, .another_category_color_gray h4 {
#   215     border-color: #E5E5E5 !important;
#   216 }
#   217
#   218 .another_category_color_gray * {
#   219     color: #909090 !important;
#   220 }
#   221
#   222 .another_category_color_gray th a.current {
#   223     border-color: #909090 !important;
#   224 }
#   225
#   226 .another_category_color_gray h4, .another_category_color_gray h4 a {
#   227     color: #737373 !important;
#   228 }
#   229
#   230 .another_category_color_red, .another_category_color_red h4 {
#   231     border-color: #F6D4D3 !important;
#   232 }
#   233
#   234 .another_category_color_red * {
#   235     color: #E86869 !important;
#   236 }
#   237
#   238 .another_category_color_red th a.current {
#   239     border-color: #E86869 !important;
#   240 }
#   241
#   242 .another_category_color_red h4, .another_category_color_red h4 a {
#   243     color: #ED0908 !important;
#   244 }
#   245
#   246 .another_category_color_green, .another_category_color_green h4 {
#   247     border-color: #CCE7C8 !important;
#   248 }
#   249
#   250 .another_category_color_green * {
#   251     color: #64C05B !important;
#   252 }
#   253
#   254 .another_category_color_green th a.current {
#   255     border-color: #64C05B !important;
#   256 }
#   257
#   258 .another_category_color_green h4, .another_category_color_green h4 a {
#   259     color: #3EA731 !important;
#   260 }
#   261
#   262 .another_category_color_blue, .another_category_color_blue h4 {
#   263     border-color: #C8DAF2 !important;
#   264 }
#   265
#   266 .another_category_color_blue * {
#   267     color: #477FD6 !important;
#   268 }
#   269
#   270 .another_category_color_blue th a.current {
#   271     border-color: #477FD6 !important;
#   272 }
#   273
#   274 .another_category_color_blue h4, .another_category_color_blue h4 a {
#   275     color: #1960CA !important;
#   276 }
#   277
#   278 .another_category_color_violet, .another_category_color_violet h4 {
#   279     border-color: #E1CEEC !important;
#   280 }
#   281
#   282 .another_category_color_violet * {
#   283     color: #9D64C5 !important;
#   284 }
#   285
#   286 .another_category_color_violet th a.current {
#   287     border-color: #9D64C5 !important;
#   288 }
#   289
#   290 .another_category_color_violet h4, .another_category_color_violet h4 a {
#   291     color: #7E2CB5 !important;
#   292 }
#   293      </style>
#   294      <link
#       href="https://tistory1.daumcdn.net/tistory_admin/userblog/userblog-2f42fbf504a9342b3fd8297ed4953c4384cc5c1f/s
#       tatic/style/revenue.css" rel="stylesheet" type="text/css">
#   295       <link href="https://stackframe.tistory.com" rel="canonical"/>
#   296       <!-- BEGIN STRUCTURED_DATA -->
#   297       <script type="application/ld+json">
#   298        {"@context":"http://schema.org","@type":"WebSite","url":"/","potentialAction":{"@type":"SearchAction",
#       "target":"/search/{search_term_string}","query-input":"required name=search_term_string"}}
#   299       </script>
#   300       <!-- END STRUCTURED_DATA -->
#   301       <link
#       href="https://tistory1.daumcdn.net/tistory_admin/userblog/userblog-2f42fbf504a9342b3fd8297ed4953c4384cc5c1f/s
#       tatic/style/dialog.css" rel="stylesheet" type="text/css"/>
#   302       <link href="//t1.daumcdn.net/tistory_admin/www/style/top/font.css" rel="stylesheet" type="text/css"/>
#   303       <link
#       href="https://tistory1.daumcdn.net/tistory_admin/userblog/userblog-2f42fbf504a9342b3fd8297ed4953c4384cc5c1f/s
#       tatic/style/postBtn.css" rel="stylesheet" type="text/css"/>
#   304       <link
#       href="https://tistory1.daumcdn.net/tistory_admin/userblog/userblog-2f42fbf504a9342b3fd8297ed4953c4384cc5c1f/s
#       tatic/style/tistory.css" rel="stylesheet" type="text/css"/>
#   305       <script
#       src="https://tistory1.daumcdn.net/tistory_admin/userblog/userblog-2f42fbf504a9342b3fd8297ed4953c4384cc5c1f/st
#       atic/script/common.js" type="text/javascript">
#   306       </script>
#   307      </link>
#   308     </meta>
#   309    </meta>
#   310   </meta>
#   311  </head>
#   312  <body class="color-gray post-type-text" id="tt-body-index">
#   313   <div id="acc-nav">
#   314    <a href="#content">
#   315     본문 바로가기
#   316    </a>
#   317   </div>
#   318   <div id="wrap">
#   319    <header id="header">
#   320     <h1>
#   321      <a href="https://stackframe.tistory.com/">
#   322       stackframe
#   323      </a>
#   324     </h1>
#   325     <button class="mobile-menu" type="button">
#   326      <span>
#   327       메뉴
#   328      </span>
#   329     </button>
#   330     <div class="menu">
#   331      <nav id="gnb">
#   332       <ul class="tt_category">
#   333        <li class="">
#   334         <a class="link_tit" href="/category">
#   335          분류 전체보기
#   336          <span class="c_cnt">
#   337           (43)
#   338          </span>
#   339         </a>
#   340         <ul class="category_list">
#   341          <li class="">
#   342           <a class="link_item" href="/category/Linux">
#   343            Linux
#   344            <span class="c_cnt">
#   345             (26)
#   346            </span>
#   347           </a>
#   348           <ul class="sub_category_list">
#   349            <li class="">
#   350             <a class="link_sub_item" href="/category/Linux/Archlinux">
#   351              Archlinux
#   352              <span class="c_cnt">
#   353               (2)
#   354              </span>
#   355             </a>
#   356            </li>
#   357            <li class="">
#   358             <a class="link_sub_item" href="/category/Linux/systemd">
#   359              systemd
#   360              <span class="c_cnt">
#   361               (13)
#   362              </span>
# ...
#   579          갑자기 문득 네이버 클라우드 플랫폼과 구글 클라우드 플랫폼의 서버/VM 인스턴스의 인터넷 네트워크
#       대역폭이 어느정도 되는지 궁금하여 실험해봤습니다. 처음에는 제 컴퓨터와 각각 iperf3로 대역폭을 측정해봤으나 제
#       인터넷 계약이 500Mbps이고 둘 다 그걸 뛰어넘는 대역폭을 가지고 있어서 제대로 측정이 되지 않았습니다. 그래서
#       서로 iperf3를 실행하여 측정해봤습니다. 먼저 네이버 클라우드 플랫폼의 Sever는 아래와 같이 정했습니다. 한국
#       리전 g2 standard vCPU 4개, 16GB RAM SSD 50GB CentOS 7.8 64bit 구글 클라우드 플랫폼의 VM 인스턴스는 아래와
#       같습니다. 한국 서울 리전 e2-standard-4(vCPU 4개, 16GB RAM) 20GB CentOS 8 ..
#   580         </span>
#   581        </a>
#   582       </div>
#   583      </div>
#   584      <div class="pagination">
#   585       <a class="prev no-more-prev">
#   586        이전
#   587       </a>
#   588       <a href="/?page=1">
#   589        <span class="selected">
#   590         1
#   591        </span>
#   592       </a>
#   593       <a href="/?page=2">
#   594        <span class="">
#   595         2
#   596        </span>
#   597       </a>
#   598       <a href="/?page=3">
#   599        <span class="">
#   600         3
#   601        </span>
#   602       </a>
#   603       <a href="/?page=4">
#   604        <span class="">
#   605         4
#   606        </span>
#   607       </a>
#   608       <a>
#   609        <span class="">
#   610         ···
#   611        </span>
#   612       </a>
#   613       <a href="/?page=6">
#   614        <span class="">
#   615         6
#   616        </span>
#   617       </a>
#   618       <a class="next" href="/?page=2">
#   619        다음
#   620       </a>
#   621      </div>
#   622     </article>
#   623    </section>
#   624    <hr/>
#   625    <footer id="footer">
#   626     <p class="copyright">
#   627      DESIGN BY
#   628      <a href="#">
#   629       TISTORY
#   630      </a>
#   631      <a class="admin" href="https://stackframe.tistory.com/manage">
#   632       관리자
#   633      </a>
#   634     </p>
#   635    </footer>
#   636   </div>
#   637   <script src="https://tistory1.daumcdn.net/tistory/2982309/skin/images/script.js?_version_=1624887901">
#   638   </script>
#   639   <div class="#menubar menu_toolbar">
#   640    <h2 class="screen_out">
#   641     티스토리툴바
#   642    </h2>
#   643   </div>
#   644   <div class="#menubar menu_toolbar">
#   645   </div>
#   646   <div class="layer_tooltip">
#   647    <div class="inner_layer_tooltip">
#   648     <p class="desc_g">
#   649     </p>
#   650    </div>
#   651   </div>
#   652   <div id="editEntry" style="position:absolute;width:1px;height:1px;left:-100px;top:-100px">
#   653   </div>
#   654   <!-- SyntaxHighlight - START -->
#   655   <link href="//cdnjs.cloudflare.com/ajax/libs/highlight.js/10.7.3/styles/atom-one-dark-reasonable.min.css"
#       rel="stylesheet"/>
#   656   <script src="//cdnjs.cloudflare.com/ajax/libs/highlight.js/10.7.3/highlight.min.js">
#   657   </script>
#   658   <script src="//cdnjs.cloudflare.com/ajax/libs/highlight.js/10.7.3/languages/delphi.min.js">
#   659   </script>
#   660   <script src="//cdnjs.cloudflare.com/ajax/libs/highlight.js/10.7.3/languages/php.min.js">
#   661   </script>
#   662   <script src="//cdnjs.cloudflare.com/ajax/libs/highlight.js/10.7.3/languages/python.min.js">
#   663   </script>
#   664   <script defer="" src="//cdnjs.cloudflare.com/ajax/libs/highlight.js/10.7.3/languages/r.min.js">
#   665   </script>
#   666   <script src="//cdnjs.cloudflare.com/ajax/libs/highlight.js/10.7.3/languages/ruby.min.js">
#   667   </script>
#   668   <script defer="" src="//cdnjs.cloudflare.com/ajax/libs/highlight.js/10.7.3/languages/scala.min.js">
#   669   </script>
#   670   <script src="//cdnjs.cloudflare.com/ajax/libs/highlight.js/10.7.3/languages/shell.min.js">
#   671   </script>
#   672   <script src="//cdnjs.cloudflare.com/ajax/libs/highlight.js/10.7.3/languages/sql.min.js">
#   673   </script>
#   674   <script defer="" src="//cdnjs.cloudflare.com/ajax/libs/highlight.js/10.7.3/languages/swift.min.js">
#   675   </script>
#   676   <script defer="" src="//cdnjs.cloudflare.com/ajax/libs/highlight.js/10.7.3/languages/typescript.min.js">
#   677   </script>
#   678   <script defer="" src="//cdnjs.cloudflare.com/ajax/libs/highlight.js/10.7.3/languages/vbnet.min.js">
#   679   </script>
#   680   <script>
#   681    hljs.initHighlightingOnLoad();
#   682   </script>
#   683   <!-- SyntaxHighlight - END -->
#   684   <div style="margin:0; padding:0; border:none; background:none; float:none; clear:none; z-index:0">
#   685   </div>
#   686   <script
#       src="https://tistory1.daumcdn.net/tistory_admin/userblog/userblog-2f42fbf504a9342b3fd8297ed4953c4384cc5c1f/st
#       atic/script/common.js" type="text/javascript">
#   687   </script>
#   688   <script type="text/javascript">
#   689    window.roosevelt_params_queue = window.roosevelt_params_queue || [{channel_id: 'dk', channel_label:
#       '{tistory}'}]
#   690   </script>
#   691   <script async="async" src="//t1.daumcdn.net/midas/rt/dk_bt/roosevelt_dk_bt.js" type="text/javascript">
#   692   </script>
#   693   <script>
#   694    window.tiara =
#       {"svcDomain":"user.tistory.com","section":"블로그","trackPage":"블로그홈_보기","page":"블로그홈","key":"29823
#       09","customProps":{"userId":"0","blogId":"2982309","entryId":"null","role":"guest","trackPage":"블로그홈_보기
#       ","filterTarget":false},"entry":null,"kakaoAppKey":"3e6ddd834b023f24221217e370daed18","appUserId":"null"}
#   695   </script>
#   696   <script src="https://t1.daumcdn.net/tistory_admin/frontend/tiara/v1.0.5/index.js" type="module">
#   697   </script>
#   698   <script defer="true" nomodule="true"
#       src="https://t1.daumcdn.net/tistory_admin/frontend/tiara/v1.0.5/polyfills-legacy.js">
#   699   </script>
#   700   <script defer="true" nomodule="true"
#       src="https://t1.daumcdn.net/tistory_admin/frontend/tiara/v1.0.5/index-legacy.js">
#   701   </script>
#   702  </body>
#   703 </html>
#   704

# %%
text = soup.find_all('span', class_='title')
text2 = soup.find_all('span', class_='excerpt')

a = []
b = []

for t in text:
    a.append(t.text)

for t2 in text2:
    b.append(t2.text)

for x in range(len(a)):
    print(f'제목: {a[x]}\n내용:\t\t{b[x][:100]}\n\t\t{b[x][100:200]}...\n')
# Out:
# 제목: systemd-detect-virt로 가상화 환경 확인하기
# 내용:		systemd는 systemd-detect-virt 라는 프로그램을 포함하고 있습니다. 이를통해 현재 가상화 환경에서 실행되는지, 어떤 가상화 기술을 사용하는지 확인할 수 있습니다
# 		. 사용방법은 단순히 쉘에서 systemd-detect-virt를 실행하면 됩니다.먼저 어떠한 가상화도 사용하지 않았다면 none이라는 문자열이 출력됩니다.라즈베리파이에서 syst...
#
# 제목: Solo V2 킥스타터에서 펀딩 중
# 내용:		3개월 전에 제가 Solo Tap을 구입했었는데 이제 업그레이드 버전인 Solo V2가 킥스타터에서 펀딩을 하고 있습니다. https://www.kickstarter.com/pro
# 		jects/conorpatrick/solo-v2-safety-net-against-phishing/ 이전부터 새로운 버전이 나오는걸 기다리고 있었고 열리자마자 바로 후원을 신청했습...
#
# 제목: 고급 보호 프로그램으로 구글 계정을 더 안전하게 보호하기
# 내용:		이전 글에서 설명한 2단계 인증으로는 일반인들에겐 충분히 안전한 보안이 될 수 있습니다. 다만 자신이 대기업의 임원이거나 정치인 등 APT 공격이나 집중 공격 타깃이 되기 쉬운 경
# 		우 더 강력한 보안을 원하게 될 수 있습니다. 구글은 이런 사람들을 위해서 Advanced Protection Program(고급 보호 프로그램)을 제공하고 있습니다. 이 프로그램...
#
# 제목: FIDO 인증키로 Google 2단계 인증 설정하기
# 내용:		구글은 타인이 무단으로 계정에 접근하지 못하도록 비밀번호 이외에 다양한 인증 방법을 제공합니다. 기본적으로 의심스러운 로그인이 발견되면 실 소유자가 사용하는 스마트폰으로 알림을 보
# 		내거나 알맞은 번호를 누르도록 합니다. 하지만 이것들로는 완벽하게 로그인 하는걸 막을 수 없으므로 구글은 2단계 인증을 제공합니다. 구글 계정의 2단계 인증은 https://mya...
#
# 제목: SoloKeys Solo Tap 구입
# 내용:		전까지는 다른 FIDO2 인증키를 사용하고 있었으나 실험이나 연구용으로도 사용하여 자주 초기화하게 되어서 아예 실제 사용 용도로 SoloKeys Solo Tap을 구입하게 되었습니
# 		다. 사실 9월 말에 주문하였지만 엄청나게 느린 배송 속도와 이런저런 배송 문제 때문에 드디어 받아보게 되었습니다. 주문하면 이렇게 검정색, 빨간색 두 색상의 커버도 함께 들어있습...
#
# 제목: FIDO와 Webauthn이란 무엇인가
# 내용:		FIDO는 Fast IDentity Online의 약자로 사용자 인증 프로토콜에 대한 표준입니다. FIDO를 준수하는 시스템에서는 어떤 제조사가 인증키를 만들든 FIDO만 따른다면
# 		 사용가능합니다. 기본적으로 FIDO는 Challenge-response로 인증합니다. 인증키를 사용할 곳에 미리 공개키를 등록시켜두고 이후 인증할 때 challenge를 받고 개...
#
# 제목: PostgreSQL의 Schema
# 내용:		PostgreSQL에는 schema(스키마)라는 개념이 있습니다. schema는 하나의 데이터베이스에 다수 존재할 수 있으며 table, sequence 등의 객체가 특정 sche
# 		ma에 속해지게 됩니다. 이를 통해 테이블들을 분류하고 사용자가 특정 schema에만 접근할 수 있도록하면 테이블 하나하나에 권한을 설정 할 필요없이 용도에 따른 접근제한을 걸 수...
#
# 제목: 네이버 클라우드 플랫폼과 구글 클라우드 플랫폼 가상서버 인터넷 네트워크 대역폭 측정
# 내용:		갑자기 문득 네이버 클라우드 플랫폼과 구글 클라우드 플랫폼의 서버/VM 인스턴스의 인터넷 네트워크 대역폭이 어느정도 되는지 궁금하여 실험해봤습니다. 처음에는 제 컴퓨터와 각각 ip
# 		erf3로 대역폭을 측정해봤으나 제 인터넷 계약이 500Mbps이고 둘 다 그걸 뛰어넘는 대역폭을 가지고 있어서 제대로 측정이 되지 않았습니다. 그래서 서로 iperf3를 실행하여...
